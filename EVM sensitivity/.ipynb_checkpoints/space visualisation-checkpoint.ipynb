# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import contextily as cx

# %%
df_disagg = pd.read_csv('population_disagg.csv').set_index('GM_CODE')
df_disagg
# Out:
#          baseline  aant_inw_original  between_45_64  AANT_INW
# GM_CODE
# GM0014     2841.0            13349.0         2168.0    233273
# GM0034     2841.0            12287.0         2759.0    214715
# GM0037     2841.0             1817.0         2956.0     31754
# GM0047     2841.0             1569.0         2956.0     27417
# GM0050     2841.0             1309.0         3055.0     22879
# ...           ...                ...            ...       ...
# GM1966     2841.0             2737.0         2956.0     47834
# GM1969     2841.0             3644.0         2858.0     63678
# GM1970     2841.0             2603.0         2759.0     45481
# GM1978     2841.0             2525.0         2661.0     44130
# GM1979     2841.0             2609.0         2956.0     45587
#
# [352 rows x 4 columns]

# %%
dfg = gpd.read_file('shapes_gemeente/gemeente_2020_v2.shp').set_index('GM_CODE')
#dfg = dfg['geometry']
#dfg.index.duplicated()

# %%
dfg = dfg[dfg['H2O'] == 'NEE']

# %%
dfg.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 355 entries, GM0003 to GM1978
# Columns: 180 entries, GM_NAAM to geometry
# dtypes: float64(96), geometry(1), int64(80), object(3)
# memory usage: 512.0+ KB

# %%
df2 = df_disagg.join(dfg['geometry'])

# %%
df2 = gpd.GeoDataFrame(df2[df2['geometry'].notna()],geometry='geometry')

# %%
df2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 351 entries, GM0014 to GM1978
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   baseline           351 non-null    float64
#  1   aant_inw_original  351 non-null    float64
#  2   between_45_64      351 non-null    float64
#  3   AANT_INW           351 non-null    int64
#  4   geometry           351 non-null    geometry
# dtypes: float64(3), geometry(1), int64(1)
# memory usage: 16.5+ KB

# %%
df2.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
df2['area km2'] = df2.area / 1000000

# %%
df2['AANT_INW density'] = df2['AANT_INW'] / df2['area km2']

# %%
df2['AANT_INW density']['GM0014']
# Out:
# 1178.3817085920143

# %%
df2[['baseline', 'geometry']]
# Out:
#          baseline                                           geometry
# GM_CODE
# GM0014     2841.0  POLYGON ((227979.943 584879.819, 227981.153 58...
# GM0034     2841.0  MULTIPOLYGON (((142993.687 482642.725, 142993....
# GM0037     2841.0  POLYGON ((258898.084 557450.734, 258897.941 55...
# GM0047     2841.0  POLYGON ((250623.405 572132.283, 250964.875 57...
# GM0050     2841.0  MULTIPOLYGON (((170535.750 487005.250, 170543....
# ...           ...                                                ...
# GM1963     2841.0  MULTIPOLYGON (((84447.802 413939.947, 84447.80...
# GM1966     2841.0  MULTIPOLYGON (((217037.735 601967.991, 217043....
# GM1969     2841.0  POLYGON ((211363.510 585818.360, 211364.156 58...
# GM1970     2841.0  MULTIPOLYGON (((207769.575 603284.528, 207773....
# GM1978     2841.0  POLYGON ((102822.359 432749.868, 102817.412 43...
#
# [351 rows x 2 columns]

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize=(30, 20))
df2.plot(ax=ax1,column='baseline',legend=True,cmap='Reds',edgecolor='black',linewidth=0.1,alpha=1)
ax1.set_title('Baseline')
ax1.set_axis_off()

df2.plot(ax=ax2,column='aant_inw_original',legend=True,cmap='Reds',edgecolor='black',linewidth=0.1,alpha=0.9)
ax2.set_title('Original')
ax2.set_axis_off()

df2.plot(ax=ax3,column='between_45_64',legend=True,cmap='Reds',edgecolor='black',linewidth=0.1,alpha=0.9)
ax3.set_title('between 45 and 64')
ax3.set_axis_off()
#fig.patch.set_facecolor('xkcd:taupe')
#cx.add_basemap(ax, crs=df2.crs)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df2.plot(ax=ax,column='AANT_INW density',legend=True,cmap='Reds',edgecolor='black',linewidth=0.1,alpha=0.9)
ax.set_title('Population distribution in the Netherlands')
ax.set_axis_off()

# %%
df2.describe()

# %%
df2['AANT_INW'].loc[df2['AANT_INW'] == 873338]
# Out:
# GM_CODE
# GM0363    873338
# GM0363    873338
# Name: AANT_INW, dtype: int64

# %%
df2['AANT_INW']['GM0363']

# %%
df2['area km2']['GM1970']

# %%
df2.index.duplicated()
df2.index.drop_duplicates()
df2.index.drop_duplicates()
# Out:
# Index(['GM0014', 'GM0034', 'GM0037', 'GM0047', 'GM0050', 'GM0059', 'GM0060',
#        'GM0072', 'GM0074', 'GM0080',
#        ...
#        'GM1954', 'GM1955', 'GM1959', 'GM1960', 'GM1961', 'GM1963', 'GM1966',
#        'GM1969', 'GM1970', 'GM1978'],
#       dtype='object', name='GM_CODE', length=351)
